# %% [markdown]
# ## Task#1

# %%
import pandas as pd
from sklearn.datasets import load_wine

wine_data = load_wine(as_frame=True)
df = wine_data.frame
df.head(7)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
# 5    14.20        1.76  2.45               15.2      112.0           3.27
# 6    14.39        1.87  2.45               14.6       96.0           2.50
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# ...

# %% [markdown]
# ## Task#2

# %%
def dataset_shape(dataset):
    return dataset.shape

dataset_shape(df)
# Out:
# (178, 14)

# %% [markdown]
# ## Task#3

# %%
from sklearn.model_selection import train_test_split

X = df.drop('target', axis=1)
y = df['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

X_train.shape, X_test.shape
# Out:
# ((124, 13), (54, 13))

# %% [markdown]
# ## Task#4

# %%
import numpy as np

numeric_cols = X.select_dtypes(include=np.number).columns
desc_stats = pd.DataFrame({
    'mean': X[numeric_cols].mean(),
    'median': X[numeric_cols].median(),
    'variance': X[numeric_cols].var(),
    'std_dev': X[numeric_cols].std()
})
desc_stats
# Out:
#                                     mean   median      variance     std_dev
# alcohol                        13.000618   13.050      0.659062    0.811827
# malic_acid                      2.336348    1.865      1.248015    1.117146
# ash                             2.366517    2.360      0.075265    0.274344
# alcalinity_of_ash              19.494944   19.500     11.152686    3.339564
# magnesium                      99.741573   98.000    203.989335   14.282484
# total_phenols                   2.295112    2.355      0.391690    0.625851
# flavanoids                      2.029270    2.135      0.997719    0.998859
# nonflavanoid_phenols            0.361854    0.340      0.015489    0.124453
# proanthocyanins                 1.590899    1.555      0.327595    0.572359
# color_intensity                 5.058090    4.690      5.374449    2.318286
# hue                             0.957449    0.965      0.052245    0.228572
# ...

# %% [markdown]
# ## Task#5

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df['alcohol'], bins=15, color='skyblue', edgecolor='black')
plt.title("Histogram of Alcohol Feature")
plt.xlabel("Alcohol")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Task#6

# %%
num_list = [12, 45, 23, 67, 34, 89, 21, 43, 56, 78, 90, 11, 32, 55, 66]
list_mean = np.mean(num_list)
list_median = np.median(num_list)

list_mean, list_median
# Out:
# (np.float64(48.13333333333333), np.float64(45.0))

# %% [markdown]
# ## Task#7

# %%
def summary_statistics(values):
    values_array = np.array(values)
    summary = {
        'count': len(values_array),
        'mean': np.mean(values_array),
        'min': np.min(values_array),
        'max': np.max(values_array),
        'std_dev': np.std(values_array, ddof=1)
    }
    return summary

summary_statistics(num_list)
# Out:
# {'count': 15,
#  'mean': np.float64(48.13333333333333),
#  'min': np.int64(11),
#  'max': np.int64(90),
#  'std_dev': np.float64(26.25116777447833)}

# %% [markdown]
# ## Task#8

# %%
random_matrix = np.random.randint(1, 51, size=(6,6))
random_matrix
# Out:
# array([[49,  9, 13, 16, 12, 24],
#        [31, 40, 38, 49,  3, 44],
#        [39, 28, 14, 29, 21,  2],
#        [ 3,  2, 49,  2, 12, 32],
#        [33, 19,  5, 27, 24, 37],
#        [ 4, 27, 35, 37,  4, 49]], dtype=int32)

# %% [markdown]
# ## Task#9

# %%
df.to_csv("wine_dataset.csv", index=False)
csv_df = pd.read_csv("wine_dataset.csv")

csv_df.info()
csv_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %% [markdown]
# ## Task#10

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train[['alcohol']], y_train)

lr.coef_, lr.intercept_
# Out:
# (array([-0.30919967]), np.float64(4.959863033398118))

# %% [markdown]
# ## Task#11

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df['alcohol_scaled'] = scaler.fit_transform(df[['alcohol']])
df['alcohol_scaled'].head(10)
# Out:
# 0    0.842105
# 1    0.571053
# 2    0.560526
# 3    0.878947
# 4    0.581579
# 5    0.834211
# 6    0.884211
# 7    0.797368
# 8    1.000000
# 9    0.744737
# Name: alcohol_scaled, dtype: float64

# %% [markdown]
# ## Task#12

# %%
df.groupby('target')['alcohol'].mean()
# Out:
# target
# 0    13.744746
# 1    12.278732
# 2    13.153750
# Name: alcohol, dtype: float64

# %% [markdown]
# ## Task#13

# %%
plt.figure(figsize=(8,5))
plt.scatter(df['alcohol'], df['malic_acid'], c=df['target'], cmap='viridis', edgecolor='k')
plt.xlabel("Alcohol")
plt.ylabel("Malic Acid")
plt.title("Scatterplot: Alcohol vs Malic Acid")
plt.colorbar(label='Target Class')
plt.show()

# %% [markdown]
# ## Task#14

# %%
import seaborn as sns

plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Task#15

# %%
df.to_csv("wine_dataset_cleaned.csv", index=False)
print("Cleaned dataset saved as 'wine_dataset_cleaned.csv'")
# Out:
# Cleaned dataset saved as 'wine_dataset_cleaned.csv'
